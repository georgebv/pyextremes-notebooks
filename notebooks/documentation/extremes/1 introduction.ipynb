# %%
import pandas as pd

from pyextremes import __version__, get_extremes
from pyextremes.plotting import plot_extremes
print("pyextremes", __version__)
# Out:
# pyextremes 2.2.3

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv(
    "../../../data/battery_wl.csv",
    index_col=0,
    parse_dates=True,
    squeeze=True,
)
data = (
    data
    .sort_index(ascending=True)
    .astype(float)
    .dropna()
)
data = data.loc[pd.to_datetime("1980"):pd.to_datetime("1995")]
data = data - (data.index.array - pd.to_datetime("1992")) / pd.to_timedelta("365.2425D") * 2.87e-3

# %% [markdown]
# # Block Maxima

# %%
extremes = get_extremes(
    ts=data,
    method="BM",
    block_size="365.2425D",
    min_last_block=0.7,
)
fig, ax = plot_extremes(
    ts=data,
    extremes=extremes,
    extremes_method="BM",
    extremes_type="high",
    block_size="365.2425D",
    figsize=(8, 5),
)
fig.savefig("bm.png", dpi=96, bbox_inches="tight")

# %% [markdown]
# # Peaks Over Threshold

# %%
extremes = get_extremes(
    ts=data,
    method="POT",
    threshold=1.25,
    r="24H",
)
fig, ax = plot_extremes(
    ts=data,
    extremes=extremes,
    extremes_method="POT",
    extremes_type="high",
    threshold=1.25,
    figsize=(8, 5),
)
fig.savefig("pot.png", dpi=96, bbox_inches="tight")
